# %%
import pandas as pd
import numpy as np

# %%
s3 = pd.Series(np.array([4, 9, 16, 25, 36, 49, 64]))
result = s3[s3 > 20]
print("Элементы больше 20:")
print(result)
# Out:
# Элементы больше 20:
# 3    25
# 4    36
# 5    49
# 6    64
# dtype: int64
